# %%
import pandas as pd
import nltk

messages = pd.read_csv('spamhamdata.csv',sep="\t",names=["label","message"])

# %%
messages

# %%
import re
from nltk.corpus import stopwords
nltk.download('stopwords')

# %%
from nltk.stem import  WordNetLemmatizer

sst = WordNetLemmatizer()

# %%
corpus = []

for i in range (0,len(messages)):
    review = re.sub("[^a-zA-Z]", " ", messages['message'][i])
    review = review.lower()
    review = review.split()
    review = [sst.lemmatize(word)for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(max_features=500, binary=False, ngram_range=(1,1))

X = tfidf.fit_transform(corpus).toarray()

# %%
X
